# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from fastai.vision import *

# %%
path = Path('/notebooks'); print(path)
data_path = path
labels = pd.read_csv('/notebooks/train_labels.csv')
work_path = path/'models'
# Out:
# /notebooks

# %%
labels.rename(columns={'id': 'name'})
labels['id']='train/'+labels['id']+'.tif'

# %%
data = ImageDataBunch.from_df(data_path,
                              labels,
                              #test='test',
                              ds_tfms=get_transforms(do_flip=True,
                                                    flip_vert=True,
                                                    max_lighting=0.1,
                                                    max_warp=0.),
                              size=64).normalize(imagenet_stats)

# %%
data.show_batch(2, figsize=(10,7))

# %%
arch = models.resnet50

def getLearner():
    return cnn_learner(data,
                       arch,
                       metrics=[accuracy, AUROC()],
                       model_dir=work_path)

# %%
lr_rates = []
losses = []
wds = []

iterations=600

learn = getLearner()

# %%
# wd = 0.0001
wd = 0.0001

learn.lr_find(wd=wd, num_it=iterations)

lr_rates.append(learn.recorder.lrs)
losses.append(learn.recorder.losses)
wds.append(wd)

learn.recorder.plot()

# Reset learn
learn = getLearner()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='503' class='' max='2750', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       18.29% [503/2750 00:32<02:25 1.9667]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# wd = 0.001
wd = 0.001

learn.lr_find(wd=wd, num_it=iterations)

lr_rates.append(learn.recorder.lrs)
losses.append(learn.recorder.losses)
wds.append(wd)

learn.recorder.plot()

# Reset learn
learn = getLearner()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='490' class='' max='2750', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       17.82% [490/2750 00:32<02:29 2.1774]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# wd = 0.01
wd = 0.01

learn.lr_find(wd=wd, num_it=iterations)

lr_rates.append(learn.recorder.lrs)
losses.append(learn.recorder.losses)
wds.append(wd)

learn.recorder.plot()

# Reset learn
learn = getLearner()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='490' class='' max='2750', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       17.82% [490/2750 00:32<02:28 2.1136]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# wd = 0.1
wd = 0.1

learn.lr_find(wd=wd, num_it=iterations)

lr_rates.append(learn.recorder.lrs)
losses.append(learn.recorder.losses)
wds.append(wd)

learn.recorder.plot()

# Reset learn
learn = getLearner()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='505' class='' max='2750', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       18.36% [505/2750 00:33<02:26 2.1684]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# wd = 1
wd = 1

learn.lr_find(wd=wd, num_it=iterations)

lr_rates.append(learn.recorder.lrs)
losses.append(learn.recorder.losses)
wds.append(wd)

learn.recorder.plot()

# Reset learn
learn = getLearner()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='511' class='' max='2750', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       18.58% [511/2750 00:33<02:25 1.4619]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# wd = 10
wd = 10

learn.lr_find(wd=wd, num_it=iterations)

lr_rates.append(learn.recorder.lrs)
losses.append(learn.recorder.losses)
wds.append(wd)

learn.recorder.plot()

# Reset learn
learn = getLearner()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='481' class='' max='2750', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       17.49% [481/2750 00:32<02:31 0.6644]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
_, ax = plt.subplots(1,1)
min_y = 0.5
max_y = 1.2

for i in range(len(losses)):
    ax.plot(lr_rates[i], losses[i])
    min_y = min(np.asarray(losses[i]).min(), min_y)
    
ax.set_ylabel("Loss")
ax.set_xlabel("Learning Rate")
ax.set_xscale('log')

ax.set_xlim((1e-4, 1e0))
ax.set_ylim((min_y - 0.2*min_y, max_y))

ax.legend(wds)
ax.xaxis.set_major_formatter(plt.FormatStrFormatter('%.0e'))
